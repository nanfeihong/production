 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LARK.csv
# 2025-06-09 00:37:32,891, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NKSH.csv
# 2025-06-09 00:37:32,909, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LAZ.csv
# 2025-06-09 00:37:32,926, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/WTTR.csv
# 2025-06-09 00:37:32,935, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SGRP.csv
# 2025-06-09 00:37:32,958, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AVH.csv
# 2025-06-09 00:37:32,970, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/VCRA.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data:

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224560 entries, 0 to 224559
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       224560 non-null  datetime64[ns]
#  1   Open       224555 non-null  float64
#  2   High       224555 non-null  float64
#  3   Low        224555 non-null  float64
#  4   Close      224555 non-null  float64
#  5   Adj Close  224555 non-null  float64
#  6   Volume     224555 non-null  float64
#  7   source     224560 non-null  object
#  8   ticker     224560 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 15.4+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['DENN',
#  'CODI',
#  'PCTY',
#  'VCTR',
#  'BPY',
#  'GHIV',
#  'JJN',
#  'GSK',
#  'VBIV',
#  'PDLB',
#  'APOP',
#  'SCPL',
#  'DIN',
#  'TRUP',
#  'KNX',
#  'ATCX',
#  'EDD',
#  'CASS',
#  'CHT',
#  'FUE',
#  'DUK',
#  'TEAF',
#  'DWSN',
#  'CSFL',
#  'CLPS',
#  'BHFAL',
#  'HESM',
#  'UAMY',
#  'DCF',
#  'CAH',
#  'CMSA',
#  'DPHCU',
#  'OZK',
#  'GNAF',
#  'SFBC',
#  'FAM',
#  'GIL',
#  'YCBD',
#  'ELAN',
#  'GNSS',
#  'BMTC',
#  'AXDX',
#  'AVNS',
#  'PRU',
#  'MDRX',
#  'NWBI',
#  'MSEX',
#  'ANF',
#  'FUTU',
#  'ONB',
#  'BKYI',
#  'GNTY',
#  'STAG',
#  'LARK',
#  'NKSH',
#  'LAZ',
#  'WTTR',
#  'SGRP',
#  'AVH',
#  'VCRA']

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time
import shutil

# %%
temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")
shutil.rmtree(csv_dir, ignore_errors=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")
os.makedirs(csv_dir, exist_ok=True)

# %%
start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2025-06-09 00:37:59,584, 473192941.py, 5, INFO, Writing data ((224560, 9)) to csv took 2.1630704402923584 seconds.
# 2025-06-09 00:37:59,585, 473192941.py, 6, INFO, CSV file size 25.555873 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2025-06-09 00:38:11,933, 817812245.py, 7, INFO, Writing dd ((224560, 9)) to parquet took 0.8668513298034668 seconds.
# 2025-06-09 00:38:11,934, 817812245.py, 8, INFO, Parquet file size 8.724302999999999 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
dd_shift = dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)
# Out:
# /tmp/ipykernel_6007/102405636.py:1: UserWarning: `meta` is not specified, inferred from partial data.
# Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#
#   dd_shift = dd_px.groupby('ticker', group_keys=False).apply(

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year Close_lag_1  Returns
# npartitions=60
# ANF             datetime64[ns]  float64  float64  float64  float64   float64  float64  string  int32     float64  float64
# APOP                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# YCBD                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# YCBD                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(8d1f806), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x7f8ba6cf60c0>, meta=<no_default>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# ticker
# ANF    2012-01-03  49.580002  50.259998  48.810001  48.889999  36.535461
# ANF    2012-01-04  48.669998  49.009998  47.040001  47.259998  35.317352
# ANF    2012-01-05  46.369999  46.700001  44.520000  45.889999  34.293556
# ANF    2012-01-06  46.009998  46.009998  44.849998  44.910000  33.561188
# ANF    2012-01-09  44.299999  45.700001  43.560001  45.630001  34.099251
# ...           ...        ...        ...        ...        ...        ...
# YCBD   2020-03-26   0.920000   0.980000   0.832000   0.930000   0.930000
# YCBD   2020-03-27   0.950000   0.950000   0.855000   0.888000   0.888000
# YCBD   2020-03-30   0.920000   0.950000   0.831000   0.851000   0.851000
# YCBD   2020-03-31   0.870000   0.930000   0.840000   0.930000   0.930000
# YCBD   2020-04-01   0.910000   0.920000   0.819000   0.862000   0.862000
#
#            Volume    source  Year  Close_lag_1   Returns
# ticker
# ANF     2024700.0   ANF.csv  2012          NaN       NaN
# ANF     2864500.0   ANF.csv  2012    48.889999 -0.033340
# ANF     4151700.0   ANF.csv  2012    47.259998 -0.028989
# ANF     2426700.0   ANF.csv  2012    45.889999 -0.021355
# ANF     4531600.0   ANF.csv  2012    44.910000  0.016032
# ...           ...       ...   ...          ...       ...
# YCBD     869700.0  YCBD.csv  2020     0.919000  0.011970
# YCBD     321300.0  YCBD.csv  2020     0.930000 -0.045161
# YCBD     481300.0  YCBD.csv  2020     0.888000 -0.041667
# YCBD     624800.0  YCBD.csv  2020     0.851000  0.092832
# YCBD     387900.0  YCBD.csv  2020     0.930000 -0.073118
#
# [224560 rows x 11 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()
# Out:
# 2025-06-09 00:39:54,516, data_manager.py, 53, INFO, Processing sample of tickers
# 2025-06-09 00:39:54,518, data_manager.py, 64, INFO, Getting file list from ../../05_src/data/prices_csv/
# 2025-06-09 00:39:54,541, data_manager.py, 66, INFO, Found 8049 files in ../../05_src/data/prices/
# 2025-06-09 00:39:54,541, data_manager.py, 74, INFO, Selecting sample of files
# 2025-06-09 00:39:54,542, data_manager.py, 80, INFO, Selected 30 files
# 2025-06-09 00:39:54,543, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/DDLS.csv
# 2025-06-09 00:39:54,543, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/DDLS.csv
# 2025-06-09 00:39:54,553, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:54,673, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/SMED.csv
# 2025-06-09 00:39:54,673, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SMED.csv
# 2025-06-09 00:39:54,690, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:55,108, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/SOL.csv
# 2025-06-09 00:39:55,109, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SOL.csv
# 2025-06-09 00:39:55,119, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:55,363, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/FRME.csv
# 2025-06-09 00:39:55,364, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/FRME.csv
# 2025-06-09 00:39:55,386, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:56,081, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/UGL.csv
# 2025-06-09 00:39:56,081, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/UGL.csv
# 2025-06-09 00:39:56,099, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:56,344, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/SEAC.csv
# 2025-06-09 00:39:56,345, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SEAC.csv
# 2025-06-09 00:39:56,359, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:56,844, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/KIRK.csv
# 2025-06-09 00:39:56,845, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KIRK.csv
# 2025-06-09 00:39:56,863, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:57,248, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/QTRX.csv
# 2025-06-09 00:39:57,249, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/QTRX.csv
# 2025-06-09 00:39:57,254, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:57,356, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/GAL.csv
# 2025-06-09 00:39:57,358, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/GAL.csv
# 2025-06-09 00:39:57,378, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:57,652, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/PHM.csv
# 2025-06-09 00:39:57,653, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PHM.csv
# 2025-06-09 00:39:57,674, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:58,576, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/AGTC.csv
# 2025-06-09 00:39:58,577, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AGTC.csv
# 2025-06-09 00:39:58,587, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:58,721, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/ASC.csv
# 2025-06-09 00:39:58,722, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ASC.csv
# 2025-06-09 00:39:58,732, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:58,878, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/RVNC.csv
# 2025-06-09 00:39:58,878, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RVNC.csv
# 2025-06-09 00:39:58,892, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:59,047, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/FCOM.csv
# 2025-06-09 00:39:59,048, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/FCOM.csv
# 2025-06-09 00:39:59,058, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:59,210, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/AFINP.csv
# 2025-06-09 00:39:59,210, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AFINP.csv
# 2025-06-09 00:39:59,216, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:59,253, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/IMV.csv
# 2025-06-09 00:39:59,254, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IMV.csv
# 2025-06-09 00:39:59,269, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:59,503, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/EFT.csv
# 2025-06-09 00:39:59,504, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/EFT.csv
# 2025-06-09 00:39:59,524, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:39:59,853, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/IMGN.csv
# 2025-06-09 00:39:59,854, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IMGN.csv
# 2025-06-09 00:39:59,870, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:40:00,472, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/AXP.csv
# 2025-06-09 00:40:00,472, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AXP.csv
# 2025-06-09 00:40:00,495, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:40:01,444, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/ARE.csv
# 2025-06-09 00:40:01,445, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ARE.csv
# 2025-06-09 00:40:01,462, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:40:01,918, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/CRY.csv
# 2025-06-09 00:40:01,919, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CRY.csv
# 2025-06-09 00:40:01,940, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:40:02,475, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/AB.csv
# 2025-06-09 00:40:02,476, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AB.csv
# 2025-06-09 00:40:02,507, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:40:03,185, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/PARR.csv
# 2025-06-09 00:40:03,186, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PARR.csv
# 2025-06-09 00:40:03,197, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:40:03,380, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/BUD.csv
# 2025-06-09 00:40:03,380, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BUD.csv
# 2025-06-09 00:40:03,392, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:40:03,691, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/LSST.csv
# 2025-06-09 00:40:03,692, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/LSST.csv
# 2025-06-09 00:40:03,699, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:40:03,835, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/LACQU.csv
# 2025-06-09 00:40:03,836, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LACQU.csv
# 2025-06-09 00:40:03,854, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:40:03,938, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/SJT.csv
# 2025-06-09 00:40:03,938, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SJT.csv
# 2025-06-09 00:40:03,957, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:40:04,699, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/PSET.csv
# 2025-06-09 00:40:04,700, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/PSET.csv
# 2025-06-09 00:40:04,708, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:40:04,799, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/MFNC.csv
# 2025-06-09 00:40:04,799, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MFNC.csv
# 2025-06-09 00:40:04,815, data_manager.py, 101, INFO, Saving data by year
# 2025-06-09 00:40:05,231, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/IQ.csv
# 2025-06-09 00:40:05,232, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IQ.csv
# 2025-06-09 00:40:05,240, data_manager.py, 101, INFO, Saving data by year

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2025-06-09 00:40:10,384, data_manager.py, 131, INFO, Creating features data.
# 2025-06-09 00:40:10,388, data_manager.py, 141, INFO, Loading price data from ../../05_src/data/prices/
# 2025-06-09 00:40:10,633, data_manager.py, 150, INFO, Creating features
# /workspaces/production/01_materials/labs/../../05_src/stock_prices/data_manager.py:154: UserWarning: `meta` is not specified, inferred from partial data.
# Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#
#   .apply(
# 2025-06-09 00:40:10,639, data_manager.py, 175, INFO, Saving features to ../../05_src/data/features/stock_features
